# %% [markdown]
# <a href="https://colab.research.google.com/github/kirthika20072005/Customer-chatbotNM/blob/main/phase_3_customer_chatbotAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlid addst
# Install dependencies
# !pip install scikit-learn --quiet

# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report
from google.colab import files
uploaded = files.upload()

# Load the balanced dataset
file_path = "Balanced_Chatbot_Intent_Dataset.csv"
df = pd.read_csv(file_path)

# Prepare the data
X = df['utterance']
y = df['intent']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# Create a pipeline with TF-IDF and Logistic Regression
model = make_pipeline(TfidfVectorizer(), LogisticRegression(max_iter=1000))
model.fit(X_train, y_train)

# Evaluate model performance
y_pred = model.predict(X_test)
print("📊 Classification Report:\n")
print(classification_report(y_test, y_pred))

# Start interactive chatbot
def chatbot():
    print("\n🤖 Intelligent Chatbot Assistant")
    print("Type 'exit' to quit.\n")
    while True:
        user_input = input("🗣️ You: ")
        if user_input.lower() == 'exit':
            print("👋 Goodbye!")
            break
        prediction = model.predict([user_input])[0]
        print(f"🤖 Intent Detected: **{prediction}**\n")

# Run the chatbot
chatbot()
# Out:
#      <input type="file" id="files-eb9fcde1-a678-41f1-9085-570da7f297f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb9fcde1-a678-41f1-9085-570da7f297f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
